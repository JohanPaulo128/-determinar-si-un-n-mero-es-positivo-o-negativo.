# %% [markdown]
# <a href="https://colab.research.google.com/github/JohanPaulo128/-determinar-si-un-n-mero-es-positivo-o-negativo./blob/main/UIII_Act_1_ejemplos_de_if_Johan_0016.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Johan Paulo Aros Reveles Nl = 04 Fecha 6/Mayo/2026
# #### Ejemplo de if, if else, if elif

# %% [markdown]
# #### Ejemplo de if

# %%
# 1: Sentencia if simple con operadores aritméticos y relacionales
# Este código verifica si un número es par utilizando el operador de módulo.
numero = 10  # Asigna el valor 10 a la variable 'numero' [11].
if numero % 2 == 0:  # '%' calcula el resto de la división entre 2 y '==' compara si es igual a 0 [6, 8].
    print("El número es par.")  # Si el resto es 0, imprime el mensaje [12].
# Out:
# El número es par.

# %%
# 1: Sentencia if simple con operadores aritméticos y relacionales
# Este código verifica si un número es par utilizando el operador de módulo.
numero = 10  # Asigna el valor 10 a la variable 'numero' [11].
if numero % 2 == 0:  # '%' calcula el resto de la división entre 2 y '==' compara si es igual a 0 [6, 8].
    print("El número es par.")  # Si el resto es 0, imprime el mensaje [12].
# Out:
# El número es par.

# %%
# 2: Identificación de año bisiesto (Combinación compleja)
# Este ejemplo utiliza una lógica más avanzada con operadores de módulo y lógicos para verificar reglas de calendario

anio = 2024  # Define el año a evaluar [11].
# Un año es bisiesto si es divisible por 4 y no por 100, o si es divisible por 400 [15, 16].
if (anio % 4 == 0 and anio % 100 != 0) or (anio % 400 == 0):
    print(f"{anio} es un año bisiesto.")  # f-string para insertar el valor de la variable en el texto [17].
else:
    print(f"{anio} no es un año bisiesto.")  # Mensaje si no se cumplen las condiciones de bisiesto [15].
# Out:
# 2024 es un año bisiesto.

# %%
# 2: Identificación de año bisiesto (Combinación compleja)
# Este ejemplo utiliza una lógica más avanzada con operadores de módulo y lógicos para verificar reglas de calendario

anio = 2023  # Define el año a evaluar [11].
# Un año es bisiesto si es divisible por 4 y no por 100, o si es divisible por 400 [15, 16].
if (anio % 4 == 0 and anio % 100 != 0) or (anio % 400 == 0):
    print(f"{anio} es un año bisiesto.")  # f-string para insertar el valor de la variable en el texto [17].
else:
    print(f"{anio} no es un año bisiesto.")  # Mensaje si no se cumplen las condiciones de bisiesto [15].
# Out:
# 2023 no es un año bisiesto.

# %%
#3. Verificacion de numeros( uso de if, if else, if elif y operadores raciolanes)
# Ejemplo de clasificación de un número
numero = int(input("Ingresa un número: "))  # Solicita un dato al usuario y lo convierte a entero (int) [1].

if numero > 0:                              # Evalúa si el número es mayor que 0 usando el operador relacional '>' [1].
    print("El número es positivo.")         # Si la condición anterior es verdadera, imprime que es positivo [1].
elif numero < 0:                            # Si no fue mayor a 0, evalúa si es menor que 0 usando el operador '<' [1].
    print("El número es negativo.")         # Si esta segunda condición es verdadera, informa que es negativo [1].
else:                                       # Se ejecuta si ninguna de las condiciones anteriores se cumplió [1].
    print("El número es cero.")             # Al no ser ni mayor ni menor a 0, imprime que el número es cero [1].
# Out:
# Ingresa un número: 20
# El número es positivo.

# %%
#3. Verificacion de numeros( uso de if, if else, if elif y operadores raciolanes)
# Ejemplo de clasificación de un número
numero = int(input("Ingresa un número: "))  # Solicita un dato al usuario y lo convierte a entero (int) [1].

if numero > 0:                              # Evalúa si el número es mayor que 0 usando el operador relacional '>' [1].
    print("El número es positivo.")         # Si la condición anterior es verdadera, imprime que es positivo [1].
elif numero < 0:                            # Si no fue mayor a 0, evalúa si es menor que 0 usando el operador '<' [1].
    print("El número es negativo.")         # Si esta segunda condición es verdadera, informa que es negativo [1].
else:                                       # Se ejecuta si ninguna de las condiciones anteriores se cumplió [1].
    print("El número es cero.")             # Al no ser ni mayor ni menor a 0, imprime que el número es cero [1].
# Out:
# Ingresa un número: -15
# El número es negativo.

# %%
#3. Verificacion de numeros( uso de if, if else, if elif y operadores raciolanes)
# Ejemplo de clasificación de un número
numero = int(input("Ingresa un número: "))  # Solicita un dato al usuario y lo convierte a entero (int) [1].

if numero > 0:                              # Evalúa si el número es mayor que 0 usando el operador relacional '>' [1].
    print("El número es positivo.")         # Si la condición anterior es verdadera, imprime que es positivo [1].
elif numero < 0:                            # Si no fue mayor a 0, evalúa si es menor que 0 usando el operador '<' [1].
    print("El número es negativo.")         # Si esta segunda condición es verdadera, informa que es negativo [1].
else:                                       # Se ejecuta si ninguna de las condiciones anteriores se cumplió [1].
    print("El número es cero.")             # Al no ser ni mayor ni menor a 0, imprime que el número es cero [1].
# Out:
# Ingresa un número: 0
# El número es cero.

# %%
#4: Sentencia if-elif-else integrando todos los operadores
#Este código categoriza el desempeño de un estudiante basándose en un puntaje, aplicando un bono si el examen fue extra largo.
puntaje_base = 75  # Puntaje obtenido por el estudiante [11].
bono_extra = 10  # Puntos adicionales por dificultad [5].
total = puntaje_base + bono_extra  # Operador aritmético '+' para calcular el puntaje final [5].

if total >= 90:  # Verifica si el total es mayor o igual a 90 [8].
    print("Calificación: Excelente")
elif total >= 70 and total < 90:  # 'and' combina dos comparaciones relacionales [8, 10].
    print("Calificación: Aceptable")  # Se ejecuta si el total está en el rango [70, 90) [14].
elif total >= 60:  # Evalúa esta opción solo si las anteriores fueron falsas [1].
    print("Calificación: Suficiente")
else:
    print("Calificación: Insuficiente")  # Acción por defecto si nada anterior se cumplió [1].
# Out:
# Calificación: Aceptable

# %%
#4: Sentencia if-elif-else integrando todos los operadores
#Este código categoriza el desempeño de un estudiante basándose en un puntaje, aplicando un bono si el examen fue extra largo.
puntaje_base = 35  # Puntaje obtenido por el estudiante [11].
bono_extra = 10  # Puntos adicionales por dificultad [5].
total = puntaje_base + bono_extra  # Operador aritmético '+' para calcular el puntaje final [5].

if total >= 90:  # Verifica si el total es mayor o igual a 90 [8].
    print("Calificación: Excelente")
elif total >= 70 and total < 90:  # 'and' combina dos comparaciones relacionales [8, 10].
    print("Calificación: Aceptable")  # Se ejecuta si el total está en el rango [70, 90) [14].
elif total >= 60:  # Evalúa esta opción solo si las anteriores fueron falsas [1].
    print("Calificación: Suficiente")
else:
    print("Calificación: Insuficiente")  # Acción por defecto si nada anterior se cumplió [1].
# Out:
# Calificación: Insuficiente

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/JohanPaulo128/UIII-Act-1-ejemplo-de-if-Johan-0016/refs/heads/main/UIII%20Act1%20infografiaifelse11.png)
